# %%
import os, sys
module_path = os.path.abspath(os.path.join('..'))
sys.path.append(module_path)

import pandas as pd
from tqdm import tqdm
from src.clustering import Cluster

# %matplotlib inline


text = pd.read_csv('../data/talk_radio.csv')
clustering = Cluster(text.sentences)
results = clustering(method='kmeans', vectorizer=None, 
                     reduce_dim=None, viz=True, n_clusters=10)
# Out:
# Top terms per cluster:
# Cluster 0 (117 items): mhm | yeah | oh | know | well | ooh | nah | right | god | whoa
# Cluster 1 (2411 items): like | know | one | people | really | would | get | said | well | time
# Cluster 2 (1716 items): dot | com | one | news | five | org | twenty | boston | nine | two
# Cluster 3 (1590 items): know | think | people | going | like | would | really | one | right | mean
# Cluster 4 (859 items): eight | seven | six | hundred | five | one | three | dot | com | zero
# Cluster 5 (627 items): president | fbi | trump | news | investigation | think | attorney | clinton | michael | interview
# Cluster 6 (261 items): yeah | nah | oh | know | whoa | right | man | well | okay | god
# Cluster 7 (1078 items): know | get | like | money | five | one | going | hundred | right | got
# Cluster 8 (473 items): music | nineteen | know | one | like | jazz | song | years | little | really
# Cluster 9 (868 items): chemical | weapons | syria | russia | strikes | us | attack | president | syrian | regime
